# %%
#SimpleRNN

# %%
from keras.datasets import imdb
from keras.preprocessing import sequence

# %%
max_features = 10000
maxlen = 500
batch_size = 32

# %%
(input_train,y_train),(input_test,y_test) = imdb.load_data(
                                            num_words=max_features)
print(len(input_train))
print(len(input_test))
# Out:
# 25000
# 25000

# %%
input_train =sequence.pad_sequences(input_train,maxlen=maxlen)
input_test = sequence.pad_sequences(input_test,maxlen=maxlen)
print(input_train.shape)
print(input_test.shape)
# Out:
# (25000, 500)
# (25000, 500)

# %%
from keras.layers import Dense,Embedding,SimpleRNN
from keras.models import Sequential
from keras import models
model = Sequential()
model.add(Embedding(max_features,32))
model.add(SimpleRNN(32))
model.add(Dense(1,activation='sigmoid'))
model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['acc'])
history = model.fit(input_train,y_train,epochs=10,batch_size=128,validation_split=0.2)
# Out:
# Train on 20000 samples, validate on 5000 samples
# Epoch 1/10
# 20000/20000 [==============================] - 52s 3ms/step - loss: 0.5496 - acc: 0.7167 - val_loss: 0.4543 - val_acc: 0.7916
# Epoch 2/10
# 20000/20000 [==============================] - 49s 2ms/step - loss: 0.3528 - acc: 0.8540 - val_loss: 0.4086 - val_acc: 0.8210
# Epoch 3/10
# 20000/20000 [==============================] - 51s 3ms/step - loss: 0.2807 - acc: 0.8887 - val_loss: 0.3842 - val_acc: 0.8532
# Epoch 4/10
# 20000/20000 [==============================] - 50s 3ms/step - loss: 0.2238 - acc: 0.9148 - val_loss: 0.4914 - val_acc: 0.7632
# Epoch 5/10
# 20000/20000 [==============================] - 51s 3ms/step - loss: 0.1771 - acc: 0.9338 - val_loss: 0.3770 - val_acc: 0.8634
# Epoch 6/10
# 20000/20000 [==============================] - 48s 2ms/step - loss: 0.1357 - acc: 0.9537 - val_loss: 0.4014 - val_acc: 0.8628
# Epoch 7/10
# 20000/20000 [==============================] - 48s 2ms/step - loss: 0.0923 - acc: 0.9685 - val_loss: 0.4133 - val_acc: 0.8454
# Epoch 8/10
# 20000/20000 [==============================] - 48s 2ms/step - loss: 0.0654 - acc: 0.9790 - val_loss: 0.4390 - val_acc: 0.8488
# Epoch 9/10
# 20000/20000 [==============================] - 49s 2ms/step - loss: 0.0415 - acc: 0.9869 - val_loss: 0.4853 - val_acc: 0.8604
# Epoch 10/10
# 20000/20000 [==============================] - 50s 2ms/step - loss: 0.0397 - acc: 0.9890 - val_loss: 0.5952 - val_acc: 0.8320

# %%
import matplotlib.pyplot as plt
def my_plot(h):  
    acc = h['acc']
    val_acc = h['val_acc']
    loss = h['loss']
    val_loss = h['val_loss']
    epochs = range(1,len(acc)+1)

    plt.plot(epochs,acc,'r',label='Training acc')
    plt.plot(epochs,val_acc,'b',label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()

    plt.figure()
    plt.plot(epochs,loss,'r',label='Training loss')
    plt.plot(epochs,val_loss,'b',label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()
    
    plt.show()
my_plot(history.history)

# %%
#using LSTM

# %%
from keras.layers import Dense,Embedding,LSTM
from keras.models import Sequential
from keras import models
model1 = Sequential()
model1.add(Embedding(max_features,32))
model1.add(LSTM(32))
model1.add(Dense(1,activation='sigmoid'))
model1.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['acc'])
history = model1.fit(input_train,y_train,epochs=10,batch_size=128,validation_split=0.2)
# Out:
# Train on 20000 samples, validate on 5000 samples
# Epoch 1/10
# 20000/20000 [==============================] - 160s 8ms/step - loss: 0.4966 - acc: 0.7721 - val_loss: 0.5366 - val_acc: 0.7724
# Epoch 2/10
# 20000/20000 [==============================] - 156s 8ms/step - loss: 0.2979 - acc: 0.8826 - val_loss: 0.3010 - val_acc: 0.8724
# Epoch 3/10
# 20000/20000 [==============================] - 154s 8ms/step - loss: 0.2379 - acc: 0.9095 - val_loss: 0.3305 - val_acc: 0.8682
# Epoch 4/10
# 20000/20000 [==============================] - 154s 8ms/step - loss: 0.1990 - acc: 0.9253 - val_loss: 0.2931 - val_acc: 0.8760
# Epoch 5/10
# 20000/20000 [==============================] - 154s 8ms/step - loss: 0.1791 - acc: 0.9333 - val_loss: 0.3029 - val_acc: 0.8904
# Epoch 6/10
# 20000/20000 [==============================] - 155s 8ms/step - loss: 0.1619 - acc: 0.9423 - val_loss: 0.3366 - val_acc: 0.8524
# Epoch 7/10
# 20000/20000 [==============================] - 154s 8ms/step - loss: 0.1435 - acc: 0.9492 - val_loss: 0.3243 - val_acc: 0.8718
# Epoch 8/10
# 20000/20000 [==============================] - 155s 8ms/step - loss: 0.1331 - acc: 0.9532 - val_loss: 0.5258 - val_acc: 0.8384
# Epoch 9/10
# 20000/20000 [==============================] - 155s 8ms/step - loss: 0.1270 - acc: 0.9552 - val_loss: 0.3315 - val_acc: 0.8788
# Epoch 10/10
# 20000/20000 [==============================] - 155s 8ms/step - loss: 0.1137 - acc: 0.9611 - val_loss: 0.4032 - val_acc: 0.8852

# %%
import matplotlib.pyplot as plt
def my_plot(h):  
    acc = h['acc']
    val_acc = h['val_acc']
    loss = h['loss']
    val_loss = h['val_loss']
    epochs = range(1,len(acc)+1)

    plt.plot(epochs,acc,'r',label='Training acc')
    plt.plot(epochs,val_acc,'b',label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()

    plt.figure()
    plt.plot(epochs,loss,'r',label='Training loss')
    plt.plot(epochs,val_loss,'b',label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()
    
    plt.show()
my_plot(history.history)
